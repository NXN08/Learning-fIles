# %% [markdown]
# # Importing the Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading the dataset

# %%
ds = pd.read_csv('IceCreamData.csv')

# %% [markdown]
# # Data Understanding

# %%
ds.head()
# Out:
#    Temperature     Revenue
# 0    24.566884  534.799028
# 1    26.005191  625.190122
# 2    27.790554  660.632289
# 3    20.595335  487.706960
# 4    11.503498  316.240194

# %%
ds['Temperature'].max()
# Out:
# 45.0

# %%
ds['Temperature'].min()
# Out:
# 0.0

# %%
ds['Revenue'].max()
# Out:
# 1000.0

# %%
ds['Revenue'].min()
# Out:
# 10.0

# %%
ds.isnull().sum()
# Out:
# Temperature    0
# Revenue        0
# dtype: int64

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  500 non-null    float64
#  1   Revenue      500 non-null    float64
# dtypes: float64(2)
# memory usage: 7.9 KB

# %%
ds.describe()
# Out:
#        Temperature      Revenue
# count   500.000000   500.000000
# mean     22.232225   521.570777
# std       8.096388   175.404751
# min       0.000000    10.000000
# 25%      17.122258   405.558681
# 50%      22.392791   529.368565
# 75%      27.740674   642.257922
# max      45.000000  1000.000000

# %% [markdown]
# # Data Exploration

# %%
sns.boxplot(ds['Revenue'])
# Out:
# <AxesSubplot:xlabel='Revenue'>

# %%
sns.boxplot(ds['Temperature'])
# Out:
# <AxesSubplot:xlabel='Temperature'>

# %% [markdown]
# The average revenue and temperature is between, 400 to 650 and 18 to 28 respectievely.

# %%
sns.heatmap(ds.corr(), cmap="YlGnBu", annot= True)
plt.show()

# %% [markdown]
# Revenue and Temperature has a greater correlation of 0.99.

# %%
sns.jointplot(x='Revenue',y='Temperature',data=ds,color='blue')

# %% [markdown]
# We can see that, when the temperature increases, the revenue also increases.Both features are proportional to each other.
#
# More revenue is generated between the temperature, 15 and 32.

# %%
sns.pairplot(ds)

# %% [markdown]
# # Defining the input and output variables

# %%
X = ds.iloc[:,:-1].values.reshape(-1,1)  
y = ds.iloc[:,-1].values.reshape(-1,1)

# %%
X
# Out:
# array([[24.56688442],
#        [26.00519115],
#        [27.79055388],
#        [20.59533505],
#        [11.50349764],
#        [14.35251388],
#        [13.70777988],
#        [30.83398474],
#        [ 0.97686999],
#        [31.66946458],
#        [11.45525338],
#        [ 3.66466958],
#        [18.81182403],
#        [13.62450892],
#        [39.53990899],
#        [18.48314099],
#        [25.93537514],
#        [42.51528041],
#        [29.58948056],
#        [21.77594799],
#        [25.45783637],
#        [15.21456942],
#        [22.61931574],
#        [16.25872074],
#        [23.88172478],
#        [18.97830025],
#        [15.6614643 ],
#        [29.18504465],
#        [19.02461092],
#        [35.12015142],
#        [24.18393726],
#        [15.23119012],
#        [ 8.79095281],
#        [18.23322784],
#        [35.62892497],
#        [37.05754246],
#        [22.28455032],
#        [17.51707397],
#        [31.7379196 ],
#        [17.04973761],
#        [23.0034888 ],
# ...

# %%
y
# Out:
# array([[ 534.7990284 ],
#        [ 625.1901215 ],
#        [ 660.6322888 ],
#        [ 487.7069603 ],
#        [ 316.2401944 ],
#        [ 367.9407438 ],
#        [ 308.8945179 ],
#        [ 696.7166402 ],
#        [  55.39033824],
#        [ 737.8008241 ],
#        [ 325.9684084 ],
#        [  71.16015301],
#        [ 467.4467066 ],
#        [ 289.5409341 ],
#        [ 905.4776043 ],
#        [ 469.9090332 ],
#        [ 648.2099977 ],
#        [ 921.508275  ],
#        [ 649.5611747 ],
#        [ 534.6228653 ],
#        [ 612.1539491 ],
#        [ 353.3256334 ],
#        [ 524.2361154 ],
#        [ 374.231135  ],
#        [ 523.1245467 ],
#        [ 473.6043349 ],
#        [ 402.4553204 ],
#        [ 679.3177906 ],
#        [ 517.5340283 ],
#        [ 809.6720534 ],
#        [ 528.3804165 ],
#        [ 356.0980075 ],
#        [ 237.7639106 ],
#        [ 418.1372788 ],
#        [ 809.4634112 ],
#        [ 870.7659159 ],
#        [ 550.2785159 ],
#        [ 405.6614459 ],
# ...

# %% [markdown]
# # Splitting to test and train data

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.3, random_state = 0)

# %% [markdown]
# # Building the model

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)
y_pred_train = regressor.predict(X_train)

# %%
y_pred
# Out:
# array([[697.40760182],
#        [652.67518783],
#        [664.01048102],
#        [451.14537645],
#        [664.75022673],
#        [442.05219958],
#        [583.85242913],
#        [623.3625391 ],
#        [666.7500596 ],
#        [469.23604811],
#        [546.84832099],
#        [444.08266531],
#        [622.49432909],
#        [378.73035124],
#        [368.21119457],
#        [943.18564123],
#        [891.63651167],
#        [693.5479008 ],
#        [546.07634654],
#        [421.39940399],
#        [392.08451996],
#        [596.71982427],
#        [284.91295994],
#        [654.83874688],
#        [382.05091808],
#        [413.18421083],
#        [372.17594967],
#        [510.48997583],
#        [480.14543708],
#        [457.26943784],
#        [639.55061011],
#        [283.33932566],
#        [315.67211819],
#        [470.5172469 ],
#        [559.66448707],
#        [539.8163622 ],
#        [309.24695716],
#        [508.91264932],
#        [571.29876902],
#        [731.11193473],
# ...

# %%
# Visualising the result
plt.scatter(X_train, y_train, color='orange')
plt.plot(X_train, regressor.predict(X_train), color='blue')
plt.title('Daily Revenue Generated')
plt.xlabel('Temperature')
plt.ylabel('Revenue')
plt.show()

# %%
plt.scatter(X_test, y_test, color='red')
plt.plot(X_test, regressor.predict(X_test), color='blue')
plt.title('Daily Revenue Generated')
plt.xlabel('Temperature')
plt.ylabel('Revenue')
plt.show()

# %%
print(regressor.intercept_)
print(regressor.coef_)
# Out:
# [46.91550105]
# [[21.37822239]]

# %%
pred =regressor.predict([[24.566884]])
print(pred)
# Out:
# [[572.11181061]]

# %%
from sklearn import metrics
print("MAE:", metrics.mean_absolute_error(y_test, y_pred))
print("MSE:", metrics.mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error:", np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print('R square :',metrics.r2_score(y_test, y_pred))
# Out:
# MAE: 17.976807512195343
# MSE: 503.3547092334282
# Root Mean Squared Error: 22.43556794987433
# R square : 0.9854012979456143
